# %%
#importing required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(0, 10, 50)
sinus = np.sin(x)
plt.plot(x, sinus)
plt.show()

# %%
sinus = np.sin(x)
plt.plot(x, sinus)
plt.show()

# %%
plt.plot(x,sinus,"o")
plt.show()

# %%
plt.plot(x,sinus,"*")
plt.show()

# %%
plt.plot(x,sinus,"--")
plt.show()

# %%
plt.plot(x,sinus,"-")
plt.show()

# %%
#rapid multiplot
x=np.linspace(0,10,50)
sinus=np.sin(x)
cosinus=np.cos(x)
plt.plot(x,sinus,"-b",x,sinus,"ob",x,cosinus,"--r",x,cosinus,"or")
plt.xlabel("x values")
plt.ylabel("Sin(x) and Cos(x)")
plt.title("Plotting Sin(x) and Cos(x) vs. x")
plt.show()

# %%
x=np.linspace(0,10,50)
sinus=np.sin(x)
cosinus=np.cos(x)
plt.plot(x,sinus,label='sinus',color='blue',linestyle='--',linewidth=2)
plt.plot(x,cosinus,label='cosinus',color='red',linestyle='-',linewidth=2)
plt.legend()
plt.show()

# %%
#draw a circle with radius 10 center at the origin
r=10
x=np.linspace(-10,10,100)
y=np.sqrt(r**2 - x**2)
plt.figure(figsize = (4,4))
plt.plot(x,y,"-r",linewidth=2)
plt.plot(x,-y,"-r",linewidth=2)
plt.show()

# %%
#loading dataset on to a data frame
try:
  df=pd.read_csv("/content/salary_table.csv")
except Exception as ex:
    print("Data file could not be read.")
    print("Error message:",ex)
    print("Error type:",type(ex))
else:
  print(df.head())
# Out:
#    salary  experience education management
# 0   13876           1  Bachelor          Y
# 1   11608           1      Ph.D          N
# 2   18701           1      Ph.D          Y
# 3   11283           1    Master          N
# 4   11767           1      Ph.D          N

# %%
colors = {'Bachelor':'r', "Ph.D":'g','Master':'b'}
plt.scatter(df.experience,df.salary, c=df.education.apply(lambda x:colors[x]), s=50)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery-nogrid')

# make data:
np.random.seed(1)
x = np.random.uniform(-3, 3, 256)
y = np.random.uniform(-3, 3, 256)
z = (1 - x/2 + x**5 + y**3) * np.exp(-x**2 - y**2)

# plot:
fig, ax = plt.subplots()

ax.triplot(x, y)

ax.set(xlim=(-3, 3), ylim=(-3, 3))

plt.show()
